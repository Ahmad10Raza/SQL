# %% [markdown]
# #  Explain constraints and its types?

# %% [markdown]
# In SQL, constraints are rules applied to data columns in a table. They ensure the reliability and accuracy of the data. Constraints can be applied at the column level or table level.
#
# Here are the main types of constraints in SQL:
#
# 1. **NOT NULL Constraint**: Ensures that a column cannot have a NULL value.
#
# 2. **UNIQUE Constraint**: Ensures that all values in a column are different.
#
# 3. **PRIMARY KEY Constraint**: Uniquely identifies each record in a database table. Primary keys must contain unique values and cannot be NULL.
#
# 4. **FOREIGN KEY Constraint**: Uniquely identifies a row/record in any of the given database table. It is used to prevent actions that would destroy links between tables.
#
# 5. **CHECK Constraint**: The CHECK constraint ensures that all values in a column satisfy certain conditions.
#
# 6. **DEFAULT Constraint**: Provides a default value for a column when none is specified.
#
# 7. **INDEX Constraint**: Used to create and retrieve data from the database very quickly.
#
# Here's an example of how these constraints might be used in SQL:

# %%
CREATE TABLE Employees (
    ID int NOT NULL,
    LastName varchar(255) NOT NULL,
    FirstName varchar(255),
    Age int CHECK (Age>=18),
    City varchar(255) DEFAULT 'Unknown',
    PRIMARY KEY (ID)
);

# %% [markdown]
# In this example, the ID column is the primary key column and cannot contain NULL. The Age column must be at least 18, and if no City is specified, the DEFAULT 'Unknown' will be used.

# %% [markdown]
# # Explain integrity constraints.

# %% [markdown]
# Integrity constraints are rules that help ensure the quality and accuracy of the information in a database. They enforce the business rules associated with a database and prevent the entry of invalid information into tables. There are three main types of integrity constraints:
#
# 1. **Domain Integrity**: This ensures that all entries for a given column are of the same kind and within the specified domain. For example, a column storing age values should only accept integers.
#
# 2. **Entity Integrity**: This ensures that each row or record in a table is unique. This is typically enforced using a primary key constraint, which requires that each record has a unique identifier.
#
# 3. **Referential Integrity**: This ensures that relationships between tables remain consistent. This is typically enforced using foreign key constraints. For example, if a table has a foreign key that references the primary key of another table, the database won't allow you to add a record unless there's a corresponding record in the linked table.
#
# These constraints are crucial for maintaining the accuracy and consistency of data in a relational database.

# %% [markdown]
# # Write short note on SQL. Explain various characteristics of SQL?

# %% [markdown]
# SQL, or Structured Query Language, is a standardized programming language used for managing and manipulating relational databases. It is used to perform tasks such as update data on a database, or retrieve data from a database.
#
# Here are some key characteristics of SQL:
#
# 1. **Declarative**: SQL is a declarative language. This means you only need to describe what you want to achieve, and the SQL engine takes care of how it's done.
#
# 2. **Standardized**: SQL is a standardized language that is used across different database systems. Although there are some variations in SQL syntax between different database systems, the basic SQL commands like `SELECT`, `INSERT`, `UPDATE`, `DELETE`, `CREATE`, and `DROP` can be used in nearly all systems.
#
# 3. **Querying**: SQL is primarily used to query data within a database. This is done using the `SELECT` statement.
#
# 4. **Data Manipulation**: SQL can be used to insert, update, and delete records in a database.
#
# 5. **Data Definition**: SQL allows you to define the structure of a database, including tables, fields, and the relationships between them.
#
# 6. **Access Control**: SQL also includes commands to control who has access to data and what they can do with it.
#
# 7. **Transactional Control**: SQL includes commands to control transactions, ensuring that all data manipulations within a transaction are completed or none are.
#
# 8. **Data Consistency**: SQL provides constraints to ensure data consistency in the database.
#
# 9. **Interoperability**: SQL can work with different database systems and is supported by most of the modern programming languages.
#
# 10. **Portability**: SQL scripts can be exported and imported between different systems and databases.

# %% [markdown]
# # What are the advantages and disadvantages of SQL ?

# %% [markdown]
# SQL, or Structured Query Language, is a powerful tool for managing data stored in relational database management systems. It has several advantages and disadvantages:
#
# **Advantages of SQL:**
#
# 1. **Standardized Language**: SQL is used universally across many different database systems. This makes it a versatile tool for data management.
#
# 2. **Efficient Data Management**: SQL provides efficient handling of large amounts of data.
#
# 3. **Multiple Data Views**: SQL allows different views of the same data for different users.
#
# 4. **Security**: SQL provides robust data security. It includes features for data encryption and user access control.
#
# 5. **High Performance**: SQL can handle large databases and complex queries, delivering high performance.
#
# 6. **Compatibility**: SQL is compatible with other languages like Java, C++, Python, etc., making it easy to integrate with existing systems.
#
# **Disadvantages of SQL:**
#
# 1. **Complexity**: SQL has a complex syntax that can be difficult for beginners to learn.
#
# 2. **Limited Error Messages**: SQL sometimes provides vague error messages, making debugging difficult.
#
# 3. **Cost**: While there are free versions of SQL databases, advanced features often come at a significant cost.
#
# 4. **Hardware Requirements**: Large databases require substantial hardware and system resources.
#
# 5. **Difficulties with Large Objects**: SQL can struggle with handling large objects like images or documents. These are typically stored outside the database with only a link stored in the database.
#
# 6. **Vendor-Specific Syntax**: While SQL is standardized, many vendors add extensions or tweaks to the standard SQL syntax, which can lead to compatibility issues.

# %% [markdown]
# # What are the different datatypes used in SQL ?

# %% [markdown]
# SQL data types define the type of data that can be stored in a database table's column. Here are some of the most common SQL data types:
#
# 1. **Numeric Data Types**:
#    - `INT`: For integers.
#    - `DECIMAL` or `NUMERIC`: For exact numerical values, where you specify the total number of digits and the number of digits after the decimal point.
#    - `FLOAT` or `REAL`: For floating point numbers.
#
# 2. **Date and Time Data Types**:
#    - `DATE`: For date values in the format `YYYY-MM-DD`.
#    - `TIME`: For time values in the format `HH:MI:SS`.
#    - `DATETIME`: For date and time values.
#
# 3. **String (Character) Data Types**:
#    - `CHAR`: For fixed-length strings. You specify the string length as a parameter.
#    - `VARCHAR`: For variable-length strings. You specify the maximum string length as a parameter.
#    - `TEXT`: For large strings.
#
# 4. **Binary Data Types**:
#    - `BINARY`: For binary strings of fixed length.
#    - `VARBINARY`: For binary strings of variable length.
#
# 5. **Miscellaneous Data Types**:
#    - `BOOLEAN`: For boolean values: true or false.
#    - `ENUM`: For a string object that can have only one value, chosen from a list of predefined values.
#
# Please note that the exact syntax and names of these data types can vary slightly between different database systems. Always check the documentation for your specific database system to see what data types are available.

# %% [markdown]
# # What are the different types of SQL constraints?

# %% [markdown]
# In SQL, constraints are rules applied to data columns in a table. They ensure the reliability and accuracy of the data. Here are the main types of constraints in SQL:
#
# 1. **NOT NULL Constraint**: Ensures that a column cannot have a NULL value.
#
# 2. **UNIQUE Constraint**: Ensures that all values in a column are different.
#
# 3. **PRIMARY KEY Constraint**: Uniquely identifies each record in a database table. Primary keys must contain unique values and cannot be NULL.
#
# 4. **FOREIGN KEY Constraint**: Uniquely identifies a row/record in any of the given database table. It is used to prevent actions that would destroy links between tables.
#
# 5. **CHECK Constraint**: The CHECK constraint ensures that all values in a column satisfy certain conditions.
#
# 6. **DEFAULT Constraint**: Provides a default value for a column when none is specified.
#
# 7. **INDEX Constraint**: Used to create and retrieve data from the database very quickly.
#
# These constraints help maintain the accuracy and integrity of the data in a database.

# %% [markdown]
# #  What are the different types of SQL commands ?

# %% [markdown]
# SQL commands are instructions used to communicate with a database to perform tasks, functions, and queries with data. They can be categorized into several types:
#
# 1. **Data Definition Language (DDL)**: These commands are used to define or alter the structure of the database.
#    - `CREATE`: Creates new tables, databases, or views.
#    - `ALTER`: Modifies existing database objects.
#    - `DROP`: Deletes existing tables, databases, or views.
#    - `TRUNCATE`: Removes all records from a table, including all spaces allocated for the records.
#
# 2. **Data Manipulation Language (DML)**: These commands are used to manipulate the data in the database.
#    - `SELECT`: Retrieves specific data from a database.
#    - `INSERT`: Inserts data into a table.
#    - `UPDATE`: Updates existing data within a table.
#    - `DELETE`: Deletes all records from a database table.
#
# 3. **Data Control Language (DCL)**: These commands are used to control the access to data in the database and to grant user access rights.
#    - `GRANT`: Gives a user's database privileges.
#    - `REVOKE`: Takes back permissions from a user.
#
# 4. **Transaction Control Language (TCL)**: These commands are used to manage transactions in the database.
#    - `COMMIT`: Saves the transaction permanently in the database.
#    - `ROLLBACK`: Restores the database to the last committed state.
#    - `SAVEPOINT`: Creates points within groups of transactions in which to ROLLBACK.
#
# 5. **Data Query Language (DQL)**: It is used to fetch the data from the database. The `SELECT` statement is part of DQL.
#
# These commands form the basis of interacting with and manipulating databases in SQL.

# %% [markdown]
# ## 1. DDL

# %% [markdown]
# Data Definition Language (DDL) commands in SQL are used to create, modify, and delete the structure of database objects. Here are some examples:
#
# 1. **CREATE**: This command is used to create the database or its objects (like table, index, function, views, store procedure, etc.).

# %%
CREATE TABLE Employees (
    ID INT PRIMARY KEY,
    Name VARCHAR(50),
    Age INT,
    Salary DECIMAL(10, 2)
);

# %% [markdown]
# 2. **ALTER**: This command is used to alter the structure of the database.

# %%
ALTER TABLE Employees
ADD Email VARCHAR(50);

# %% [markdown]
# 3. **DROP**: This command is used to drop the database or its objects.

# %%
DROP TABLE Employees;

# %% [markdown]
# 4. **TRUNCATE**: This command is used to remove all records from a table, including all spaces allocated for the records are removed.

# %%
TRUNCATE TABLE Employees;

# %% [markdown]
# Remember that DDL commands are auto-committed, meaning they cannot be rolled back. Once you run a DDL command, you cannot undo it.

# %% [markdown]
# ## 2. DML

# %% [markdown]
# Data Manipulation Language (DML) commands in SQL are used to manipulate the data in the database. Here are some examples:
#
# 1. **SELECT**: This command is used to select data from a database. The data returned is stored in a result table, called the result-set.

# %%
SELECT * FROM Employees;

# %% [markdown]
# 2. **INSERT**: This command is used to insert data into a table.

# %%
INSERT INTO Employees (ID, Name, Age, Salary) 
VALUES (1, 'John Doe', 30, 45000.00);

# %% [markdown]
# 3. **UPDATE**: This command is used to modify the existing records in a table.

# %%
UPDATE Employees 
SET Salary = 50000.00 
WHERE ID = 1;

# %% [markdown]
# 4. **DELETE**: This command is used to delete existing records in a table.

# %%
DELETE FROM Employees 
WHERE ID = 1;

# %% [markdown]
# Remember that DML commands can be rolled back, meaning you can undo these commands using the `ROLLBACK` command until the changes have been committed to the database.

# %% [markdown]
# ## 3. DCL

# %% [markdown]
# Data Control Language (DCL) commands in SQL are used to control the access to data in the database and to grant user access rights. Here are some examples:
#
# 1. **GRANT**: This command is used to give a user's database privileges.

# %%
GRANT SELECT, INSERT,UPDATE ON Employees TO user1;

# %% [markdown]
# 2. **REVOKE**: This command is used to take back permissions from a user.

# %%
REVOKE UPDATE ON Employees FROM user1;

# %% [markdown]
# In these examples, `user1` is the username of the database user. The `GRANT` command gives `user1` the permission to perform `SELECT`, `INSERT`, and `UPDATE` operations on the `Employees` table. The `REVOKE` command takes away the `UPDATE` permission from `user1` on the `Employees` table.

# %% [markdown]
# ## 4. TCL

# %% [markdown]
# Transaction Control Language (TCL) commands in SQL are used to manage transactions in the database. Here are some examples:
#
# 1. **COMMIT**: This command is used to save the transaction permanently in the database.

# %%
INSERT INTO Employees (ID, Name, Age, Salary) 
VALUES (1, 'John Doe', 30, 45000.00);

COMMIT;

# %% [markdown]
# 2. **ROLLBACK**: This command is used to restore the database to the last committed state. It is also used with the SAVEPOINT command to jump to a previous state in the transaction.

# %%
INSERT INTO Employees (ID, Name, Age, Salary) 
VALUES (2, 'Jane Doe', 28, 50000.00);

ROLLBACK;

# %% [markdown]
# 3. **SAVEPOINT**: This command is used to temporarily save a transaction so you can rollback to that point whenever necessary.

# %%
SAVEPOINT SP1;

INSERT INTO Employees (ID, Name, Age, Salary) 
VALUES (3, 'Jim Doe', 32, 55000.00);

ROLLBACK TO SP1;

# %% [markdown]
# In these examples, the `COMMIT` command is used to permanently save the new record added to the `Employees` table. The `ROLLBACK` command is used to undo the transaction before it's committed. The `SAVEPOINT` command creates a point in the transaction to which you can rollback.

# %% [markdown]
# # Draw an ER diagram of Hospital or Bank with showing the specialization, Aggregation, Generalization. Also convert it in to relational schemas and SQL DDL.

# %% [markdown]
# 1. Relational schemas :
# 2. branch (branch-name, branch-city, assets)
# 3. customer (customer-name, customer-street, customer-city, customer-id)
# 4. account (account-number, balance)
# 5. loan (loan-number, amount)
# 6. employee (employee-id, employee-name, telephone-number, start- date,employment length, dependent-name)
# 7. payment (payment-number, payment-amount, payment-date)
# 8. saving-account (interest-rate)
# 9. checking-account (overdraft-amount)

# %% [markdown]
# Based on the provided relational schemas, here are the SQL queries to create these tables:

# %% [markdown]
# Please note that you might need to adjust the data types and their lengths according to your specific needs. Also, you might need to add foreign keys to establish relationships between these tables based on your requirements.

# %%
from IPython.display import Image
Image(filename='images/Bank_ER_Model.png',width=1000)

# %% [markdown]
# Based on the provided relational schemas, here are the SQL queries to create these tables:

# %%
CREATE TABLE branch (
    branch_name VARCHAR(50),
    branch_city VARCHAR(50),
    assets DECIMAL(15, 2)
);

CREATE TABLE customer (
    customer_name VARCHAR(50),
    customer_street VARCHAR(100),
    customer_city VARCHAR(50),
    customer_id INT PRIMARY KEY
);

CREATE TABLE account (
    account_number INT PRIMARY KEY,
    balance DECIMAL(15, 2)
);

CREATE TABLE loan (
    loan_number INT PRIMARY KEY,
    amount DECIMAL(15, 2)
);

CREATE TABLE employee (
    employee_id INT PRIMARY KEY,
    employee_name VARCHAR(50),
    telephone_number VARCHAR(15),
    start_date DATE,
    employment_length INT,
    dependent_name VARCHAR(50)
);

CREATE TABLE payment (
    payment_number INT PRIMARY KEY,
    payment_amount DECIMAL(15, 2),
    payment_date DATE
);

CREATE TABLE saving_account (
    account_number INT PRIMARY KEY,
    interest_rate DECIMAL(5, 2)
);

CREATE TABLE checking_account (
    account_number INT PRIMARY KEY,
    overdraft_amount DECIMAL(15, 2)
);

# %% [markdown]
# Please note that you might need to adjust the data types and their lengths according to your specific needs. Also, you might need to add foreign keys to establish relationships between these tables based on your requirements.

# %% [markdown]
# #  Give the brief explanation of view.

# %% [markdown]
# In SQL, a view is a virtual table based on the result-set of an SQL statement. It contains rows and columns, just like a real table. The fields in a view are fields from one or more real tables in the database.
#
# Here are some key points about views:
#
# 1. **Simplified Complexity**: If you have a complex query that you use regularly, you can save it as a view and refer to it like a regular table.
#
# 2. **Security**: You can show only certain columns in the view and hide sensitive columns in the underlying table.
#
# 3. **Query Efficiency**: Views can provide a faster query response as they can pull data from pre-computed results.
#
# 4. **Consistency**: A view always shows the latest data. When the data in the underlying table changes, the view changes accordingly.
#
# However, it's important to note that views are not physically present. They take up only the memory necessary to store the definition of the view, not the data it presents. Also, not all views are updatable. That depends on the complexity of the SQL statement that defines the view.

# %% [markdown]
# Let's assume we have a table named `Books` with the following columns: `BookID`, `Title`, `Author`, `Category`, and `Price`. We want to create a view that only shows `Science Fiction` and `Fantasy` books. Here's how you could create such a view:

# %%
CREATE VIEW SciFi_Fantasy_Books
AS SELECT * FROM Books
WHERE Category IN ('Science Fiction', 'Fantasy');

# %% [markdown]
# This view, `SciFi_Fantasy_Books`, now acts like a virtual table that only contains books in the `Science Fiction` and `Fantasy` categories. You can query it like a regular table:

# %%
SELECT * FROM SciFi_Fantasy_Books;

# %% [markdown]
# This will return all the books in the `Science Fiction` and `Fantasy` categories. Remember, the data in the view is always up-to-date with the data in the original `Books` table.

# %% [markdown]
# #  Describe indexes in SQL.

# %% [markdown]
# In SQL, an index is a data structure that improves the speed of data retrieval operations on a database table. It works similarly to an index in a book, providing a quick way to look up data without having to search every row in a database table every time a database table is accessed.
#
# Indexes can be created using one or more columns of a database table, providing the basis for both rapid random lookups and efficient access of ordered records.
#
# Here are some key points about indexes:
#
# 1. **Performance**: Indexes can greatly improve the performance of database operations by allowing the database server to find and retrieve the data much faster.
#
# 2. **Type of Indexes**: There are several types of indexes in SQL, including unique index, bitmap index, clustered index, and non-clustered index.
#
# 3. **Space**: Indexes take up disk space. The more indexes a table has, the more disk space they require.
#
# 4. **Update Cost**: While indexes speed up data retrieval, they slow down data modification operations such as `INSERT`, `UPDATE`, and `DELETE`. This is because each time data is changed, the index must be updated as well.
#
# Here's an example of creating an index on a `Books` table for the `Author` column:

# %%
CREATE INDEX idx_books_author
ON Books (Author);

# %% [markdown]
# This index would help speed up queries that retrieve data based on the `Author` column.

# %% [markdown]
# ### Type Of index

# %% [markdown]
# There are several types of indexes in a database, each with its own characteristics and use cases. Here are some of the most common types:
#
# 1. **Clustered Index**: A clustered index determines the physical order of data in a table. It sorts and stores the data rows in the table or view based on their key values. There can be only one clustered index per table.
#
# 2. **Non-Clustered Index**: A non-clustered index doesn't sort the physical data inside the table. Instead, it creates a separate object within the table that contains the index key values and pointers to the location of each row. A table can have multiple non-clustered indexes.
#
# 3. **Unique Index**: A unique index ensures that the index key contains no duplicate values and therefore every row in the table or view is in some way unique.
#
# 4. **Composite Index**: A composite index, also known as a compound index or concatenated index, is an index on two or more columns of a table. Its key is a composite of the values of the indexed columns.
#
# 5. **Bitmap Index**: A bitmap index uses bit arrays (commonly referred to as bitmaps) and answers queries by performing bitwise logical operations on these bitmaps. It is most effective in databases with a large number of rows and low cardinality, which means the data column contains a limited number of distinct values.
#
# 6. **Covering Index or Included Index**: A covering index includes all the columns needed to process a particular query. The index contains not only the keys, but also a copy of the data for the columns specified. It can significantly speed up data retrieval but may slow down data modification.
#
# 7. **B-Tree Index**: This is the most common type of index. B-Tree stands for Balanced Tree, which keeps data sorted and allows for efficient insertion, deletion, and search operations.
#
# 8. **Spatial Index**: A spatial index is used to optimize queries for geometric data stored in a spatial column, such as the locations of geographical features.
#
# 9. **Full-Text Index**: A full-text index in SQL Server lets users and applications run full-text queries against character-based data in SQL Server tables.
#
# Remember, the type of index you choose depends on the specific workload, query form, and other factors of your database.

# %% [markdown]
# # Explain sub-query with example.

# %% [markdown]
# A subquery, also known as a nested query or inner query, is a query embedded within another SQL query. It can be used to return data that will be used in the main query as a condition to further restrict the data to be retrieved.
#
# Subqueries can be used with `SELECT`, `INSERT`, `UPDATE`, `DELETE`, and other SQL operations. They can be classified into two types: correlated and uncorrelated. A correlated subquery depends on data provided by the outer query, while an uncorrelated subquery can run independently of the outer query.
#
# Here's an example of a subquery. Let's say we have a `Sales` table with `ProductID`, `SaleDate`, and `SaleAmount` columns, and we want to find all sales of the product that has the highest `SaleAmount`.

# %%
SELECT ProductID, SaleDate, SaleAmount
FROM Sales
WHERE SaleAmount = (
    SELECT MAX(SaleAmount)
    FROM Sales
);

# %% [markdown]
# In this example, the subquery `(SELECT MAX(SaleAmount) FROM Sales)` is used to find the maximum `SaleAmount`. The main query then retrieves all sales where `SaleAmount` is equal to this maximum value. The subquery is executed first and its result is used in the main query.

# %% [markdown]
# # Write full relation operation in SQL. Explain any one of them.

# %% [markdown]
# or

# %% [markdown]
# # Explain aggregate function in SQL.

# %% [markdown]
# In SQL, relational operations are used to manipulate or retrieve data from tables. Here are some of the most common relational operations:
#
# 1. **SELECT**: This operation is used to select a subset of the data from a database. The data returned is stored in a result table.

# %%
SELECT * FROM Employees;

# %% [markdown]
# 2. **PROJECT**: This operation is used to select certain columns from the table and discard the other columns.

# %%
SELECT Name, Age FROM Employees;

# %% [markdown]
# 3. **JOIN**: This operation is used to combine rows from two or more tables, based on a related column between them.

# %%
SELECT Orders.OrderID, Customers.CustomerName
FROM Orders
INNER JOIN Customers
ON Orders.CustomerID = Customers.CustomerID;

# %% [markdown]
# 4. **UNION**: This operation is used to combine the result-set of two or more SELECT statements.

# %%
SELECT column_name(s) FROM table1
UNION
SELECT column_name(s) FROM table2;

# %% [markdown]
# 5. **INTERSECT**: This operation is used to return the intersection of two or more SELECT statements.

# %%
SELECT column_name(s) FROM table1
INTERSECT
SELECT column_name(s) FROM table2;

# %% [markdown]
# 6. **EXCEPT (or MINUS)**: This operation is used to return all the records from the first SELECT statement that are not in the second SELECT statement.

# %%
SELECT column_name(s) FROM table1
EXCEPT
SELECT column_name(s) FROM table2;

# %% [markdown]
# 7. **DIVISION**: This operation is a bit more complex and doesn't have a specific SQL command. It's used to find tuples in one table that are associated with all tuples in another table.
#
# Let's explain the JOIN operation:
#
# The JOIN operation is used to combine rows from two or more tables based on a related column between them. There are several types of JOIN operations, including INNER JOIN, LEFT JOIN, RIGHT JOIN, and FULL JOIN.
#
# For example, if you have a `Customers` table with `CustomerID`, `CustomerName`, and `ContactNumber` columns, and an `Orders` table with `OrderID`, `CustomerID`, and `OrderDate` columns, you can use the JOIN operation to combine these tables based on the `CustomerID` column, which is common to both tables:

# %% [markdown]
# #### Aggregate functions in SQL are used to perform calculations on a set of values and return a single value. They operate on a collection of values, but return a single, summarizing value. Here are some common aggregate functions:
#
# 1. **COUNT()**: Returns the number of rows in a specified column.

# %%
SELECT COUNT(column_name) FROM table_name;

# %% [markdown]
# 2. **SUM()**: Returns the sum of all values in a specified column.

# %%
SELECT SUM(column_name) FROM table_name;

# %% [markdown]
# 3. **AVG()**: Returns the average value of a specified column.

# %%
SELECT AVG(column_name) FROM table_name;

# %% [markdown]
# 4. **MIN()**: Returns the smallest value in a specified column.

# %%
SELECT MIN(column_name) FROM table_name;

# %% [markdown]
# 5. **MAX()**: Returns the largest value in a specified column.

# %%
SELECT MAX(column_name) FROM table_name;

# %% [markdown]
# 6. **GROUP_CONCAT()**: Returns a string result with the concatenated non-NULL values from a group.

# %%
SELECT GROUP_CONCAT(column_name) FROM table_name;

# %% [markdown]
# It's important to note that aggregate functions ignore NULL values in their calculations, except for the `COUNT()` function, which considers NULL values. Also, you can use the `GROUP BY` statement in conjunction with these functions to group the result-set by one or more columns.

# %%
SELECT Customers.CustomerName, Orders.OrderDate
FROM Customers
INNER JOIN Orders
ON Customers.CustomerID = Orders.CustomerID;

# %% [markdown]
# This SQL statement would return a result set that includes the `CustomerName` and `OrderDate` for every order placed by each customer.

# %% [markdown]
# #  Explain how the GROUP BY clause in SQL works.

# %% [markdown]
# The `GROUP BY` clause in SQL is used to group rows that have the same values in specified columns into aggregated data. It's often used with aggregate functions (`COUNT`, `MAX`, `MIN`, `SUM`, `AVG`) to group the result-set by one or more columns.
#
# Here's an example. Let's say we have a `Sales` table with `ProductID`, `SaleDate`, and `SaleAmount` columns, and we want to find the total sales for each product.

# %%
SELECT ProductID, SUM(SaleAmount)
FROM Sales
GROUP BY ProductID;

# %% [markdown]
# In this example, the `GROUP BY` clause groups the sales data based on the `ProductID`. The `SUM(SaleAmount)` function then calculates the total sales for each group (i.e., each product).
#
# You can also use `GROUP BY` with multiple columns. For example, if you wanted to find the total sales for each product for each day, you could do:

# %%
SELECT ProductID, SaleDate, SUM(SaleAmount)
FROM Sales
GROUP BY ProductID, SaleDate;

# %% [markdown]
# In this case, the `GROUP BY` clause groups the sales data first by `ProductID`, then within each of these groups, it groups the data by `SaleDate`.
#
# The `GROUP BY` clause is typically placed after the `FROM` or `WHERE` clause in the SQL statement. If you're using the `HAVING` clause to filter groups, `GROUP BY` always comes before `HAVING`.

# %% [markdown]
# # Discuss join and types with suitable example.

# %%
Image(filename='images/Joins.png')

# %%
Image('images/Screenshot_2024-01-17-18-14-15-00.jpg',width=1000)

# %% [markdown]
# #  Explain cursors in SQl?

# %% [markdown]
# A cursor in SQL is a database object used to manipulate rows from a result set one at a time. It's essentially a control structure used to traverse and fetch the records of a database. Cursors are commonly used when the returned rows are just too large to handle all at once.
#
# There are two main types of cursors in SQL:
#
# 1. **Implicit Cursors**: These are automatically created by SQL Server whenever an SQL statement is executed, when a SELECT statement is issued, or when a singleton SELECT is used to assign values to variables in a SQL statement. Users do not control the lifecycle of implicit cursors and have fewer options for manipulating them.
#
# 2. **Explicit Cursors**: These are created by users when they are dealing with multiple rows but operations need to be performed on one row at a time. Explicit cursors give users more control over the cursor lifecycle. They are declared, opened, fetched from, and then closed and deallocated.
#
# Here's an example of an explicit cursor:

# %%
DECLARE @ProductID int;
DECLARE product_cursor CURSOR FOR 
SELECT ProductID 
FROM Products;

OPEN product_cursor;

FETCH NEXT FROM product_cursor 
INTO @ProductID;

WHILE @@FETCH_STATUS = 0
BEGIN
   -- do something with @ProductID

   FETCH NEXT FROM product_cursor 
   INTO @ProductID;
END;

CLOSE product_cursor;
DEALLOCATE product_cursor;

# %% [markdown]
# In this example, a cursor is declared and associated with a SELECT statement that retrieves the IDs of all products. The cursor is then opened and a loop is initiated in which the next product ID is fetched from the cursor and stored in the `@ProductID` variable. This loop continues until all rows have been fetched. Finally, the cursor is closed and deallocated.
#
# Remember, while cursors can be useful, they can also be slower than set-based operations and can lock resources for a longer time, which can affect performance. Therefore, they should be used sparingly and only when necessary.

# %% [markdown]
# # Explain Sequences in SQL?

# %% [markdown]
# A sequence in SQL is a database object that generates a sequence of numbers. It is often used to auto-increment a primary key field in a table. Each time a sequence is called, it generates a new number.
#
# Here's how you can create, use, and modify a sequence in SQL:
#
# 1. **Creating a Sequence**: You can create a sequence using the `CREATE SEQUENCE` statement. For example, to create a sequence that starts at 1 and increments by 1, you could do:

# %%
CREATE SEQUENCE seq_person
START WITH 1
INCREMENT BY 1;

# %% [markdown]
# 2. **Using a Sequence**: You can use the `NEXT VALUE FOR` function to get the next number in a sequence. For example, to insert a new row into a `Persons` table with an ID generated by the `seq_person` sequence, you could do:

# %%
INSERT INTO Persons (PersonID, LastName, FirstName)
VALUES (NEXT VALUE FOR seq_person, 'Doe', 'John');

# %% [markdown]
# 3. **Modifying a Sequence**: You can modify a sequence using the `ALTER SEQUENCE` statement. For example, to restart the `seq_person` sequence with a new starting number, you could do:

# %%
ALTER SEQUENCE seq_person
RESTART WITH 10;

# %% [markdown]
# 4. **Deleting a Sequence**: You can delete a sequence using the `DROP SEQUENCE` statement. For example, to delete the `seq_person` sequence, you could do:

# %%
DROP SEQUENCE seq_person;

# %% [markdown]
# Remember, the exact syntax for sequences might vary slightly depending on the SQL database you're using. The above examples use the syntax for SQL Server.

# %% [markdown]
# # What is trigger ? Explain different trigger with example.

# %% [markdown]
# **Logon Triggers**: Logon triggers in SQL Server fire stored procedures in response to a LOGON event. This event is raised when a user sessions is being established with an instance of SQL Server, after the user has been authenticated but before the user session is actually established. Therefore, all messages originating from within this trigger would show up as error messages to the user. Logon triggers are typically used to audit and control server sessions, such as tracking login activity, restricting logins to SQL Server, or limiting the number of sessions for a specific login.
#
# Here's an example of a logon trigger:

# %%
CREATE TRIGGER connection_limit_trigger
ON ALL SERVER WITH EXECUTE AS 'sa'
FOR LOGON
AS
BEGIN
IF ORIGINAL_LOGIN()= 'TestLogin' AND
   (SELECT COUNT(*) FROM sys.dm_exec_sessions
            WHERE is_user_process = 1 AND
                  original_login_name = 'TestLogin') > 3
    ROLLBACK;
END;

# %% [markdown]
# This trigger will limit the number of sessions for the login 'TestLogin' to three.
#
# **CLR Triggers**: CLR triggers are triggers that reference a Microsoft .NET Framework assembly that is created in the Microsoft .NET Framework and uploaded in SQL Server. CLR is short for Common Language Runtime, the core component of the .NET framework. CLR triggers can be used whenever you need to reference managed code in a .NET language like C# or VB.NET. They can be used for complex computations, accessing resources outside SQL Server, or for tasks that would be cumbersome in T-SQL.
#
# Here's an example of a CLR trigger:

# %%
[Microsoft.SqlServer.Server.SqlTrigger(Name = "CLRTestTrigger", Target = "TestTable", Event = "FOR INSERT")]
public static void TestTrigger()
{
    SqlContext.Pipe.Send("Trigger FIRED");
}

# %% [markdown]
# This is a simple CLR trigger written in C# that will send a message "Trigger FIRED" whenever a new row is inserted into the `TestTable`. The .NET assembly containing this trigger would need to be uploaded to SQL Server using the `CREATE ASSEMBLY` SQL command, and then the trigger would be created referencing this assembly using the `CREATE TRIGGER` SQL command.

# %% [markdown]
# A trigger in SQL is a special type of stored procedure that automatically executes or fires when a specific event occurs in the database. Triggers are used to maintain the integrity of the data in the database and are invoked automatically when a data modification event (INSERT, UPDATE, or DELETE) occurs.
#
# There are three types of triggers in SQL:
#
# 1. **INSERT Trigger**: This trigger is fired whenever a new row is inserted into the database.

# %%
CREATE TRIGGER insert_trigger
ON table_name
FOR INSERT
AS
-- SQL statements to execute

# %% [markdown]
# 2. **UPDATE Trigger**: This trigger is fired whenever a row in the database is updated.

# %%
CREATE TRIGGER update_trigger
ON table_name
FOR UPDATE
AS
-- SQL statements to execute

# %% [markdown]
# 3. **DELETE Trigger**: This trigger is fired whenever a row is deleted from the database.

# %%
CREATE TRIGGER delete_trigger
ON table_name
FOR DELETE
AS
-- SQL statements to execute

# %% [markdown]
# For example, let's say we have a `Sales` table and we want to keep a log of all deleted sales records. We could create a DELETE trigger for this:

# %%
CREATE TRIGGER sales_delete_trigger
ON Sales
FOR DELETE
AS
INSERT INTO SalesLog
SELECT * FROM deleted;

# %% [markdown]
# In this example, the `sales_delete_trigger` is fired whenever a row is deleted from the `Sales` table. The deleted sales record is then inserted into the `SalesLog` table. The `deleted` table is a special table in SQL Server that holds the rows that were deleted by the last DELETE statement.
#
# Remember, the exact syntax for triggers might vary slightly depending on the SQL database you're using. The above examples use the syntax for SQL Server.

# %% [markdown]
# # Questions 01

# %% [markdown]
#  Consider the following relational database
# 1. employee(employee_name, s treet, city works (employee_ name,company_name, salary))
# 2. company (company_name, city)
# 3. manage (employee_name, manager_name).
#
# Give an expression in SQL to express each of the following queries :
#
# i.Find the names and cities of residence of all employees who work for XYZ bank.
#
# ii. Find the names, street address, and cities of residence of all employee who works for XYZ Bank and earn more than Rs. 10,000 per annum.
#
# iii. Find the names of all employees in this database who live in the same city as the company for which they work.

# %% [markdown]
# The SQL code to create the above relational database with the `employee`, `works`, `company`, and `manage` tables would look something like this:

# %%
CREATE TABLE employee (
    employee_name VARCHAR(100),
    street VARCHAR(100),
    city VARCHAR(100),
    PRIMARY KEY (employee_name)
);

CREATE TABLE company (
    company_name VARCHAR(100),
    city VARCHAR(100),
    PRIMARY KEY (company_name)
);

CREATE TABLE works (
    employee_name VARCHAR(100),
    company_name VARCHAR(100),
    salary DECIMAL(10, 2),
    PRIMARY KEY (employee_name, company_name),
    FOREIGN KEY (employee_name) REFERENCES employee(employee_name),
    FOREIGN KEY (company_name) REFERENCES company(company_name)
);

CREATE TABLE manage (
    employee_name VARCHAR(100),
    manager_name VARCHAR(100),
    PRIMARY KEY (employee_name, manager_name),
    FOREIGN KEY (employee_name) REFERENCES employee(employee_name),
    FOREIGN KEY (manager_name) REFERENCES employee(employee_name)
);

# %% [markdown]
# In this code:
#
# - The `employee` table has `employee_name`, `street`, and `city` columns. The `employee_name` column is the primary key.
# - The `company` table has `company_name` and `city` columns. The `company_name` column is the primary key.
# - The `works` table has `employee_name`, `company_name`, and `salary` columns. The `employee_name` and `company_name` columns together form the primary key. The `employee_name` column is a foreign key that references the `employee_name` column in the `employee` table. The `company_name` column is a foreign key that references the `company_name` column in the `company` table.
# - The `manage` table has `employee_name` and `manager_name` columns. The `employee_name` and `manager_name` columns together form the primary key. Both columns are foreign keys that reference the `employee_name` column in the `employee` table.

# %% [markdown]
# Here are the SQL queries for each of the given tasks:
#
# i. Find the names and cities of residence of all employees who work for XYZ bank.

# %%
SELECT e.employee_name, e.city
FROM employee e
JOIN works w ON e.employee_name = w.employee_name
WHERE w.company_name = 'XYZ Bank';

# %% [markdown]
# ii. Find the names, street address, and cities of residence of all employees who work for XYZ Bank and earn more than Rs. 10,000 per annum.

# %%
SELECT e.employee_name, e.street, e.city
FROM employee e
JOIN works w ON e.employee_name = w.employee_name
WHERE w.company_name = 'XYZ Bank' AND w.salary > 10000;

# %% [markdown]
# iii. Find the names of all employees in this database who live in the same city as the company for which they work.

# %%
SELECT e.employee_name
FROM employee e
JOIN works w ON e.employee_name = w.employee_name
JOIN company c ON w.company_name = c.company_name
WHERE e.city = c.city;

# %% [markdown]
# These queries assume that the schema of your tables matches the one you provided earlier. If the schema is different, you may need to adjust the column and table names accordingly.

# %%
i.
 Select E.employee_name, city
from employee E, works W
where W.company_name = ‘XYZ Bank’ and
W.employee_name = E.employee_name

ii.
 Select * from employee
where employee_name in
select employee_name from Works
where company_name=‘XYZ Bank’ and salary>10000
select E. employee_name, street address, city
from Employee as E, Works as W
where E. employee_name=W.person_name and
W.company_name = ‘XYZ Bank’ and W.salary>10000

iii.
 Select E. employee _name
from Employee as E, Works as W, Company as C
where E. employee _name=W.person_name and E.city=C.city
and W.company_name=C.company_name

# %% [markdown]
# # **Thank You!**
